# %%
import sys
import os

# 경로 설정
vc_py_path = '/Users/suengj/Documents/Code/Python/Research/VC/py'

# 경로가 존재하는지 확인
if os.path.exists(vc_py_path):
    if vc_py_path not in sys.path:
        sys.path.append(vc_py_path)    
    # import
    import VC_v0
else:
    print(f"경로가 존재하지 않습니다: {vc_py_path}")

# %%
# Round data merge
df = read_merge_save_pickle(
    file_path=round_path_US,
    file_pattern='round_*.xlsx',
    skiprows=None, # 첫줄 모두 포함
    header=0,
    column_mapping=round_column_mapping,
    output_filename='round_data_US.pkl'
)

# 결과 확인
if df is not None:
    print(f"\n=== 최종 결과 ===")
    print(f"데이터 크기: {df.shape}")
    print(f"컬럼 목록:")
    for i, col in enumerate(df.columns, 1):
        print(f"{i:2d}. {col}")
# Out:
# 경로: /Users/suengj/Documents/Code/Python/Research/VC/raw/round/US
# 파일 패턴: round_*.xlsx
# 발견된 파일 수: 19
# ✓ 성공: round_2010-11.xlsx (크기: (25130, 16))
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[58], line 23
#       1 # Round data merge
#       2
#       3 # 정리된 데이터로 병합
#       4 column_mapping = {
#       5     'Round Date': 'rounddate',
#       6     'Company Name': 'compnm',
#    (...)
#      20     'Standard US Venture Disbursement': 'disbursement'
#      21 }
# ---> 23 df = read_merge_save_pickle(
#      24     file_path=round_path_US,
#      25     file_pattern='round_*.xlsx',
#      26     skiprows=None, # 첫줄 모두 포함
#      27     header=0,
#      28     column_mapping=column_mapping,
#      29     output_filename='round_data_US.pkl'
#      30 )
#      32 # 결과 확인
#      33 if df is not None:
#
# ...

# %%
# company data merge
df = read_merge_save_pickle(
    file_path=startup_path,
    file_pattern='*.xlsx',
    skiprows=1, # 첫줄 skip
    header=0,
    column_mapping=company_column_mapping,
    output_filename='company_data.pkl'
)

# 결과 확인
if df is not None:
    print(f"\n=== 최종 결과 ===")
    print(f"데이터 크기: {df.shape}")
    print(f"컬럼 목록:")
    for i, col in enumerate(df.columns, 1):
        print(f"{i:2d}. {col}")
# Out:
# 경로: /Users/suengj/Documents/Code/Python/Research/VC/raw/startup
# 파일 패턴: *.xlsx
# 발견된 파일 수: 4
# ✓ 성공: comdta_2011-2022.xlsx (크기: (18184, 20))
# ✓ 성공: comdta_2000-2011.xlsx (크기: (18476, 20))
# ✓ 성공: comdta_1980-1999.xlsx (크기: (23194, 20))
# ✓ 성공: comdta_1970-1979.xlsx (크기: (3379, 20))
#
# === 병합 완료 ===
# 성공한 파일: 4개
# 실패한 파일: 0개
# 병합 후 데이터 크기: (63233, 20)
# 원본 컬럼: ['Company\nIPO Date', 'Company\nFounding\nDate', 'Company Current\nSituation Date', 'Company\n6-digit\nCUSIP', 'Company Current Situation', 'Company Current\nPublic Status', 'Company\nIPO Status', 'Company\nMSA Code', 'Company Name', 'Company\nNation\nCode', 'Company\nState\nCode', 'Company\nStock\nExchange,\nif Applic.', 'Company\nTicker,\nif Applic.', 'Company Industry Class', 'Company Industry Major Group', 'Company Industry Minor Group', 'Company Industry Sub-Group 1', 'Company Industry Sub-Group 2', 'Company Industry Sub-Group 3', 'Company\nZip Code']
# ✓ 컬럼명의 \n 제거됨
# ...

# %%
# VC firm data merge (US only)
df = read_merge_save_pickle(
    file_path=VC_path,
    file_pattern='VC_firm_US.xlsx',
    skiprows=None, # 첫줄 skip
    header=0,
    column_mapping=firm_column_mapping,
    output_filename='VC_firm_US.pkl'
)

# 결과 확인
if df is not None:
    print(f"\n=== 최종 결과 ===")
    print(f"데이터 크기: {df.shape}")
    print(f"컬럼 목록:")
    for i, col in enumerate(df.columns, 1):
        print(f"{i:2d}. {col}")
# Out:
# 경로: /Users/suengj/Documents/Code/Python/Research/VC/raw/firm
# 파일 패턴: VC_firm_US.xlsx
# 발견된 파일 수: 1
# ✓ 성공: VC_firm_US.xlsx (크기: (15779, 8))
#
# === 병합 완료 ===
# 성공한 파일: 1개
# 실패한 파일: 0개
# 병합 후 데이터 크기: (15779, 8)
# 원본 컬럼: ['Firm Name', 'Firm\nFounding\nDate', 'Firm\nNation\nCode', 'Firm\nState\nCode', 'Firm\nZip Code', 'Firm Type', 'Firm Investment Status', 'Firm\nMSA Code']
# ✓ 컬럼명의 \n 제거됨
# 정리 후 컬럼: ['Firm Name', 'Firm Founding Date', 'Firm Nation Code', 'Firm State Code', 'Firm Zip Code', 'Firm Type', 'Firm Investment Status', 'Firm MSA Code']
# 최종 데이터 크기: (15779, 8)
# pickle 파일 저장 완료: /Users/suengj/Documents/Code/Python/Research/VC/raw/extract/VC_firm_US.pkl
#
# === 최종 결과 ===
# 데이터 크기: (15779, 8)
# 컬럼 목록:
#  1. firmnm
#  2. firmfnd
#  3. firmnation
#  4. firmstate
#  5. firmzip
#  6. firmtype
#  7. firminvstat
#  8. firmmsa

# %%
# end of code

# %%
# # 컬럼 불일치 감지 코드
column_info, mismatch_report = detect_column_mismatches(
    file_path=round_path_US,
    file_pattern='round_*.xlsx',
    skiprows=None,
    header=0
)

# 특정 파일의 컬럼 확인
if column_info:
    print("\n=== 특정 파일의 컬럼 확인 ===")
    for f_nm, info in list(column_info.items())[:]:  # 처음 3개 파일만
        if 'error' not in info:
            print(f"{f_nm}: {info['columns']}")
