# %%
import pandas as pd
import os

# Load the .dta file
BASE_PATH = '/Users/suengj/Library/Mobile Documents/com~apple~CloudDocs/suengj/Academia/Research/03_project/00_Yang, Rhee, Ma/analysis_15May25'

df = pd.read_stata(f'{BASE_PATH}/dta_23Feb14_10.dta')

# Save as parquet with compression
df.to_parquet(f'{BASE_PATH}/raw_May15_ratio10.parquet', compression='snappy')

# %%
import os

# 변경 후 경로 확인
print(os.getcwd())
# Out:
# /Users/suengj/Documents/Code/Python/Research/VC

# %%
df.tail(3)
# Out:
#                                  coVC              leadVC  \
# 1215057  Newroad Capital Partners LLC  H.I.G. Capital LLC
# 1215058         McKesson Ventures LLC  H.I.G. Capital LLC
# 1215059      Innovation Endeavors LLC  H.I.G. Capital LLC
#
#                         comname  realized quarter    year  leadVC_dgr  \
# 1215057  Capstone Logistics LLC       0.0  20221Q  2022.0        57.0
# 1215058  Capstone Logistics LLC       0.0  20221Q  2022.0        57.0
# 1215059  Capstone Logistics LLC       0.0  20221Q  2022.0        57.0
#
#            leadVC_btw  leadVC_p75  leadVC_max  ...  downwardTie  dyad_cat  \
# 1215057  26285.371484    1.538459    1.583346  ...          1.0         4
# 1215058  26285.371484    1.538459    1.583346  ...          1.0         3
# 1215059  26285.371484    1.538459    1.583346  ...          0.0         4
#
#          dyad_cat2  dyad_cat3  mc_bp_abs_dis_max  mc_bp_dis_max  \
# 1215057          3          1           0.021600       0.380715
# ...

# %%
df.columns
# Out:
# Index(['coVC', 'leadVC', 'comname', 'realized', 'quarter', 'year',
#        'leadVC_dgr', 'leadVC_btw', 'leadVC_p75', 'leadVC_max', 'leadVC_zero',
#        'leadVC_cons', 'coVC_dgr', 'coVC_btw', 'coVC_p75', 'coVC_max',
#        'coVC_zero', 'coVC_cons', 'leadVC_type', 'coVC_type', 'leadVC_type0',
#        'coVC_type0', 'comindmnr', 'comzip', 'commsa', 'comstacode',
#        'leadVC_msa', 'leadVC_state', 'leadVC_zip', 'leadVC_fndyr', 'coVC_msa',
#        'coVC_state', 'coVC_zip', 'coVC_fndyr', 'synd_lv', 'synd_size',
#        'geoDist', 'geoDist1', 'geoDist2', 'geoDist3', 'indDist',
#        'leadVC_totalInv', 'coVC_totalInv', 'leadVC_blau', 'coVC_blau',
#        'leadVC_comDist1', 'coVC_comDist1', 'VC_zipdist', 'leadVC_com_zipdist',
#        'coVC_com_zipdist', 'leadVC_exitNum', 'coVC_exitNum', 'leadVC_ipoNum',
#        'coVC_ipoNum', 'leadVC_MnANum', 'coVC_MnANum', 'leadVC_AmtInv',
#        'coVC_AmtInv', 'leadVC_age', 'coVC_age', 'leadVC_fundcnt',
# ...

# %%
len(df)
# Out:
# 1215060

# %%
# Load the .dta file
BASE_PATH = '/Users/suengj/Library/Mobile Documents/com~apple~CloudDocs/suengj/Academia/Research/03_project/00_Yang, Rhee, Ma/analysis_15May25'

df_old = pd.read_stata(f'{BASE_PATH}/dta_23Feb14_10.dta')

# %%
df_old
# Out:
#                                  coVC                leadVC  \
# 0            Paragon Venture Partners  Brentwood Associates
# 1                 Battery Ventures LP  Brentwood Associates
# 2             Churchill International  Brentwood Associates
# 3                        ABS Ventures  Brentwood Associates
# 4                   Nielsen Audio Inc  Brentwood Associates
# ...                               ...                   ...
# 622947  Exeter Capital Partners V LP.   Endicott Capital LP
# 622948        Overwater Ventures I LP   Endicott Capital LP
# 622949      Elysian Park Ventures LLC   Endicott Capital LP
# 622950   CONTOUR VENTURE PARTNERS L P   Endicott Capital LP
# 622951    Fulcrum Equity Partners Inc   Endicott Capital LP
#
#                                              comname  realized quarter  \
# 0                               Doelz Networks, Inc.       1.0  19853Q
# 1                               Doelz Networks, Inc.       1.0  19853Q
# ...
